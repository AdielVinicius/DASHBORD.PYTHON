# %%
# importando a biblioteca do pandas
import pandas as pd

# %%
dict_test = {
    "Nome": [ "João", "Maria", "José", "Silvio", "Patricia", "leonidas","Kayo", "Morgana", "Flavio", "Elisson", "Helena"],
    "Gênero": ["Masculino", "Feminino", "Masculino", "Masculino", "Feminino", "Masc", "Masc", "fem", "masc", "Homem", "Mulher"],
    "Idade": [52, 47, 65, 34,20, 26, 38, 24, 31, 22, 18],
    "UF": ["PE", "PE", "PB", "RN", "PB", "PE", "PE", "PE", "PE", "PE", "SP"]
}

# %%
#Criando um dataframe apartir de um dicionario
df = pd.DataFrame(dict_test)

# %%
# metodo head() imprime as 5 linhas iniciais do dataframe.
df.head(3)
# Out:
#     Nome     Gênero  Idade  UF
# 0   João  Masculino     52  PE
# 1  Maria   Feminino     47  PE
# 2   José  Masculino     65  PB

# %%
#imprime as ultimas 5 linhas.
df.tail(10)
# Out:
#         Nome     Gênero  Idade  UF
# 1      Maria   Feminino     47  PE
# 2       José  Masculino     65  PB
# 3     Silvio  Masculino     34  RN
# 4   Patricia   Feminino     20  PB
# 5   leonidas       Masc     26  PE
# 6       Kayo       Masc     38  PE
# 7    Morgana        fem     24  PE
# 8     Flavio       masc     31  PE
# 9    Elisson      Homem     22  PE
# 10    Helena     Mulher     18  SP

# %%
df.describe()
# Out:
#            Idade
# count  11.000000
# mean   34.272727
# std    14.960554
# min    18.000000
# 25%    23.000000
# 50%    31.000000
# 75%    42.500000
# max    65.000000

# %%
df.columns
# Out:
# Index(['Nome', 'Gênero', 'Idade', 'UF'], dtype='object')

# %%
df.count()
# Out:
# Nome      11
# Gênero    11
# Idade     11
# UF        11
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Nome    11 non-null     object
#  1   Gênero  11 non-null     object
#  2   Idade   11 non-null     int64
#  3   UF      11 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 480.0+ bytes

# %%
df.shape
# Out:
# (11, 4)

# %%
df.sample(3)
# Out:
#       Nome     Gênero  Idade  UF
# 6     Kayo       Masc     38  PE
# 10  Helena     Mulher     18  SP
# 3   Silvio  Masculino     34  RN

# %%
from google.colab import drive
drive.mount('/content/drive', True)
# Out:
# Mounted at /content/drive

# %%
arquivo = '/content/drive/MyDrive/projeto/acidentes2021.csv'
dataset = pd.read_csv(arquivo, sep=';', header=0)
print('Base carregada com sucesso \o/')
# Out:
# Base carregada com sucesso \o/

# %%
dataset
# Out:
#             data      hora natureza_acidente    situacao          bairro  \
# 0     2021-01-01  19:44:00        COM VÍTIMA  FINALIZADA        MADALENA
# 1     2021-01-01  23:15:40        COM VÍTIMA  FINALIZADA          VÁRZEA
# 2     2021-01-02  10:54:00        COM VÍTIMA  FINALIZADA   VASCO DA GAMA
# 3     2021-01-02  11:13:00        COM VÍTIMA  FINALIZADA      BOA VIAGEM
# 4     2021-01-03  09:32:00        COM VÍTIMA  FINALIZADA  ILHA DO RETIRO
# ...          ...       ...               ...         ...             ...
# 2375  2021-12-31  11:36:00        COM VÍTIMA  FINALIZADA        ESTÂNCIA
# 2376  2021-12-31  12:56:00        COM VÍTIMA  FINALIZADA          VÁRZEA
# 2377  2021-12-31  15:00:00        COM VÍTIMA  FINALIZADA         TORREÃO
# 2378  2021-12-31  20:44:00        COM VÍTIMA   CANCELADA           PRADO
# 2379  2021-12-31  20:56:00        COM VÍTIMA   CANCELADA           IPSEP
#
#                                endereco numero detalhe_endereco_acidente  \
# ...
